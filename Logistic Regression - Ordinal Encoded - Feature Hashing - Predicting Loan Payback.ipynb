# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/playground-series-s5e11/sample_submission.csv
# /kaggle/input/playground-series-s5e11/train.csv
# /kaggle/input/playground-series-s5e11/test.csv

# %%
# Reading the training data as a pandas dataframe
train_df = pd.read_csv('/kaggle/input/playground-series-s5e11/train.csv')

# %%
# Getting a view of the dataframe
print(f'List of columns in the dataframe {train_df.columns}')
train_df.head()
# Out:
# List of columns in the dataframe Index(['id', 'annual_income', 'debt_to_income_ratio', 'credit_score',
#        'loan_amount', 'interest_rate', 'gender', 'marital_status',
#        'education_level', 'employment_status', 'loan_purpose',
#        'grade_subgrade', 'loan_paid_back'],
#       dtype='object')
#    id  annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0   0       29367.99                 0.084           736      2528.42
# 1   1       22108.02                 0.166           636      4593.10
# 2   2       49566.20                 0.097           694     17005.15
# 3   3       46858.25                 0.065           533      4682.48
# 4   4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender marital_status education_level employment_status  \
# 0          13.67  Female         Single     High School     Self-employed
# 1          12.92    Male        Married        Master's          Employed
# 2           9.76    Male         Single     High School          Employed
# 3          16.10  Female         Single     High School          Employed
# 4          10.21    Male        Married     High School          Employed
#
#          loan_purpose grade_subgrade  loan_paid_back
# 0               Other             C3             1.0
# 1  Debt consolidation             D3             0.0
# 2  Debt consolidation             C5             1.0
# 3  Debt consolidation             F1             1.0
# 4               Other             D1             1.0

# %%
order_map = {'High School': 1, 
             "Bachelor's": 2, 
             "Master's": 4, 
             "Other": 3,
             "PhD": 5}
train_df['education_level_ord'] = train_df['education_level'].map(order_map)

# %%
order_map = {'Unemployed': 1, 
             "Student": 2, 
             "Self-employed": 3, 
             "Employed": 4,
             "Retired": 5}
train_df['employment_status_ord'] = train_df['employment_status'].map(order_map)

# %%
# Splitting the columns according to its type
# Dropping the id column since it won't add any relevance to predict output

unused_col = ['id']

numeric_col = ['annual_income', 'debt_to_income_ratio', 'credit_score', 
               'loan_amount', 'interest_rate', 'education_level_ord', 'employment_status_ord']

ohe_categorical_col = ['gender', 'marital_status', 'loan_purpose']

hash_categorical_col = ['grade_subgrade']

output_col = ['loan_paid_back']

# %%
train_df = train_df.drop(['employment_status', 'education_level'], axis=1)
train_df
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 0            0       29367.99                 0.084           736
# 1            1       22108.02                 0.166           636
# 2            2       49566.20                 0.097           694
# 3            3       46858.25                 0.065           533
# 4            4       25496.70                 0.053           665
# ...        ...            ...                   ...           ...
# 593989  593989       23004.26                 0.152           703
# 593990  593990       35289.43                 0.105           559
# 593991  593991       47112.64                 0.072           675
# 593992  593992       76748.44                 0.067           740
# 593993  593993       48959.52                 0.096           752
#
#         loan_amount  interest_rate  gender marital_status        loan_purpose  \
# 0           2528.42          13.67  Female         Single               Other
# 1           4593.10          12.92    Male        Married  Debt consolidation
# 2          17005.15           9.76    Male         Single  Debt consolidation
# 3           4682.48          16.10  Female         Single  Debt consolidation
# 4          12184.43          10.21    Male        Married               Other
# ...             ...            ...     ...            ...                 ...
# 593989     20958.37          10.92  Female         Single            Business
# 593990      3257.24          14.62    Male         Single  Debt consolidation
# 593991       929.27          14.13  Female        Married  Debt consolidation
# 593992     16290.40           9.87    Male         Single  Debt consolidation
# 593993      7707.73          10.31    Male        Married           Education
#
#        grade_subgrade  loan_paid_back  education_level_ord  \
# 0                  C3             1.0                    1
# 1                  D3             0.0                    4
# 2                  C5             1.0                    1
# 3                  F1             1.0                    1
# 4                  D1             1.0                    1
# ...               ...             ...                  ...
# 593989             C3             1.0                    1
# 593990             F5             1.0                    2
# 593991             C1             1.0                    2
# 593992             B2             1.0                    2
# 593993             B3             1.0                    1
#
#         employment_status_ord
# 0                           3
# 1                           4
# 2                           4
# 3                           4
# 4                           4
# ...                       ...
# 593989                      4
# 593990                      4
# 593991                      4
# 593992                      4
# 593993                      4
#
# [593994 rows x 13 columns]

# %%
# Checking the null values
train_df.info()

# The data looks clean with no need of cleaning required
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593994 entries, 0 to 593993
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     593994 non-null  int64
#  1   annual_income          593994 non-null  float64
#  2   debt_to_income_ratio   593994 non-null  float64
#  3   credit_score           593994 non-null  int64
#  4   loan_amount            593994 non-null  float64
#  5   interest_rate          593994 non-null  float64
#  6   gender                 593994 non-null  object
#  7   marital_status         593994 non-null  object
#  8   loan_purpose           593994 non-null  object
#  9   grade_subgrade         593994 non-null  object
#  10  loan_paid_back         593994 non-null  float64
#  11  education_level_ord    593994 non-null  int64
#  12  employment_status_ord  593994 non-null  int64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 58.9+ MB

# %%
# Obtaining the descriptive stats of different available columns
train_df.describe()
# Out:
#                   id  annual_income  debt_to_income_ratio   credit_score  \
# count  593994.000000  593994.000000         593994.000000  593994.000000
# mean   296996.500000   48212.202976              0.120696     680.916009
# std    171471.442235   26711.942078              0.068573      55.424956
# min         0.000000    6002.430000              0.011000     395.000000
# 25%    148498.250000   27934.400000              0.072000     646.000000
# 50%    296996.500000   46557.680000              0.096000     682.000000
# 75%    445494.750000   60981.320000              0.156000     719.000000
# max    593993.000000  393381.740000              0.627000     849.000000
#
#          loan_amount  interest_rate  loan_paid_back  education_level_ord  \
# count  593994.000000  593994.000000   593994.000000        593994.000000
# mean    15020.297629      12.356345        0.798820             2.104959
# std      6926.530568       2.008959        0.400883             1.066256
# min       500.090000       3.200000        0.000000             1.000000
# 25%     10279.620000      10.990000        1.000000             1.000000
# 50%     15000.220000      12.370000        1.000000             2.000000
# 75%     18858.580000      13.680000        1.000000             2.000000
# max     48959.950000      20.990000        1.000000             5.000000
#
#        employment_status_ord
# count          593994.000000
# mean                3.583592
# std                 0.984760
# min                 1.000000
# 25%                 4.000000
# 50%                 4.000000
# 75%                 4.000000
# max                 5.000000

# %%
# Checking the data for different type of loan purposes
train_df['loan_paid_back'].value_counts()
# Out:
# loan_paid_back
# 1.0    474494
# 0.0    119500
# Name: count, dtype: int64

# %%
train_df = train_df.drop(unused_col, axis=1)

# %%
train_df
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            29367.99                 0.084           736      2528.42
# 1            22108.02                 0.166           636      4593.10
# 2            49566.20                 0.097           694     17005.15
# 3            46858.25                 0.065           533      4682.48
# 4            25496.70                 0.053           665     12184.43
# ...               ...                   ...           ...          ...
# 593989       23004.26                 0.152           703     20958.37
# 593990       35289.43                 0.105           559      3257.24
# 593991       47112.64                 0.072           675       929.27
# 593992       76748.44                 0.067           740     16290.40
# 593993       48959.52                 0.096           752      7707.73
#
#         interest_rate  gender marital_status        loan_purpose  \
# 0               13.67  Female         Single               Other
# 1               12.92    Male        Married  Debt consolidation
# 2                9.76    Male         Single  Debt consolidation
# 3               16.10  Female         Single  Debt consolidation
# 4               10.21    Male        Married               Other
# ...               ...     ...            ...                 ...
# 593989          10.92  Female         Single            Business
# 593990          14.62    Male         Single  Debt consolidation
# 593991          14.13  Female        Married  Debt consolidation
# 593992           9.87    Male         Single  Debt consolidation
# 593993          10.31    Male        Married           Education
#
#        grade_subgrade  loan_paid_back  education_level_ord  \
# 0                  C3             1.0                    1
# 1                  D3             0.0                    4
# 2                  C5             1.0                    1
# 3                  F1             1.0                    1
# 4                  D1             1.0                    1
# ...               ...             ...                  ...
# 593989             C3             1.0                    1
# 593990             F5             1.0                    2
# 593991             C1             1.0                    2
# 593992             B2             1.0                    2
# 593993             B3             1.0                    1
#
#         employment_status_ord
# 0                           3
# 1                           4
# 2                           4
# 3                           4
# 4                           4
# ...                       ...
# 593989                      4
# 593990                      4
# 593991                      4
# 593992                      4
# 593993                      4
#
# [593994 rows x 12 columns]

# %%
X_col = [x for x in train_df if x != 'loan_paid_back']
y_col = 'loan_paid_back'

# %%
X_col
# Out:
# ['annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'gender',
#  'marital_status',
#  'loan_purpose',
#  'grade_subgrade',
#  'education_level_ord',
#  'employment_status_ord']

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold

X = train_df[X_col]
y = train_df[y_col]

# stratified train/test split (preserve class proportions)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import check_is_fitted
from sklearn.feature_extraction import FeatureHasher
from scipy import sparse

class SklearnFeatureHasher_stringtoken(BaseEstimator, TransformerMixin):
    """
    Wrap FeatureHasher with input_type='string' but ensure each sample is an iterable
    of strings (here: a single-token list [value]).
    """
    def __init__(self, n_features=32):
        self.n_features = n_features
        self.input_type = 'string'

    def fit(self, X, y=None):
        self._hasher = FeatureHasher(n_features=self.n_features, input_type=self.input_type)
        return self

    def transform(self, X):
        # Accept Series, DataFrame (single column), 1D array, or list
        if isinstance(X, (pd.Series, pd.DataFrame)):
            arr = X.values.ravel()
        else:
            arr = np.asarray(X).ravel()

        # Convert NaNs to string (or whatever sentinel you prefer)
        arr = np.where(pd.isna(arr), '___nan___', arr).astype(str)

        # IMPORTANT: FeatureHasher(input_type='string') expects each sample to be an iterable
        # of strings (e.g. tokens). Wrap each string into a single-token list:
        samples = [[val] for val in arr]

        hashed = self._hasher.transform(samples)   # returns sparse matrix
        if not sparse.isspmatrix_csr(hashed):
            hashed = hashed.tocsr()
        return hashed

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression  # example estimator
from sklearn.feature_extraction import FeatureHasher

# 3) Create ColumnTransformer - scale numeric cols, passthrough other columns
preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(handle_unknown='ignore', sparse=False), ohe_categorical_col),
        ('hash_cat', SklearnFeatureHasher_stringtoken(n_features=32), hash_categorical_col),
        ('num', StandardScaler(), numeric_col)
    ]
)

# 6) Example: plug into a pipeline with an estimator (keeps scaling inside CV correctly)
pipeline = Pipeline([
    ('pre', preprocessor),
    ('clf', LogisticRegression(max_iter=2000))
])

pipeline.fit(X_train, y_train)
print("Train score:", pipeline.score(X_train, y_train))
print("Test score:", pipeline.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Train score: 0.898027125706289
# Test score: 0.8966826320086869

# %%
test_df = pd.read_csv('/kaggle/input/playground-series-s5e11/test.csv')

# %%
test_df = test_df.drop(unused_col, axis=1)
test_df
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            28781.05                 0.049           626     11461.42
# 1            46626.39                 0.093           732     15492.25
# 2            54954.89                 0.367           611      3796.41
# 3            25644.63                 0.110           671      6574.30
# 4            25169.64                 0.081           688     17696.89
# ...               ...                   ...           ...          ...
# 254564       92835.97                 0.068           744     29704.00
# 254565       48846.47                 0.091           634     20284.33
# 254566       20668.52                 0.096           718     26387.55
# 254567       34105.09                 0.094           739     11107.36
# 254568       45627.53                 0.118           624     19246.14
#
#         interest_rate  gender marital_status education_level  \
# 0               14.73  Female         Single     High School
# 1               12.85  Female        Married        Master's
# 2               13.29    Male         Single      Bachelor's
# 3                9.57  Female         Single      Bachelor's
# 4               12.80  Female        Married             PhD
# ...               ...     ...            ...             ...
# 254564          13.48  Female         Single      Bachelor's
# 254565           9.58  Female        Married     High School
# 254566           9.00    Male         Single        Master's
# 254567           9.81    Male         Single      Bachelor's
# 254568          11.64  Female        Married     High School
#
#        employment_status        loan_purpose grade_subgrade
# 0               Employed               Other             D5
# 1               Employed               Other             C1
# 2               Employed  Debt consolidation             D1
# 3               Employed  Debt consolidation             C3
# 4               Employed            Business             C1
# ...                  ...                 ...            ...
# 254564          Employed  Debt consolidation             B2
# 254565          Employed  Debt consolidation             D4
# 254566          Employed  Debt consolidation             C4
# 254567          Employed            Business             C2
# 254568          Employed                 Car             D3
#
# [254569 rows x 11 columns]

# %%
order_map = {'High School': 1, 
             "Bachelor's": 2, 
             "Master's": 4, 
             "Other": 3,
             "PhD": 5}
test_df['education_level_ord'] = test_df['education_level'].map(order_map)

# %%
order_map = {'Unemployed': 1, 
             "Student": 2, 
             "Self-employed": 3, 
             "Employed": 4,
             "Retired": 5}
test_df['employment_status_ord'] = test_df['employment_status'].map(order_map)

# %%
test_df = test_df.drop(['education_level', 'employment_status'], axis=1)
test_df
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0            28781.05                 0.049           626     11461.42
# 1            46626.39                 0.093           732     15492.25
# 2            54954.89                 0.367           611      3796.41
# 3            25644.63                 0.110           671      6574.30
# 4            25169.64                 0.081           688     17696.89
# ...               ...                   ...           ...          ...
# 254564       92835.97                 0.068           744     29704.00
# 254565       48846.47                 0.091           634     20284.33
# 254566       20668.52                 0.096           718     26387.55
# 254567       34105.09                 0.094           739     11107.36
# 254568       45627.53                 0.118           624     19246.14
#
#         interest_rate  gender marital_status        loan_purpose  \
# 0               14.73  Female         Single               Other
# 1               12.85  Female        Married               Other
# 2               13.29    Male         Single  Debt consolidation
# 3                9.57  Female         Single  Debt consolidation
# 4               12.80  Female        Married            Business
# ...               ...     ...            ...                 ...
# 254564          13.48  Female         Single  Debt consolidation
# 254565           9.58  Female        Married  Debt consolidation
# 254566           9.00    Male         Single  Debt consolidation
# 254567           9.81    Male         Single            Business
# 254568          11.64  Female        Married                 Car
#
#        grade_subgrade  education_level_ord  employment_status_ord
# 0                  D5                    1                      4
# 1                  C1                    4                      4
# 2                  D1                    2                      4
# 3                  C3                    2                      4
# 4                  C1                    5                      4
# ...               ...                  ...                    ...
# 254564             B2                    2                      4
# 254565             D4                    1                      4
# 254566             C4                    4                      4
# 254567             C2                    2                      4
# 254568             D3                    1                      4
#
# [254569 rows x 11 columns]

# %%
# get probability for positive class
probs = pipeline.predict_proba(test_df)[:, 1]

# %%
probs
# Out:
# array([0.94132644, 0.98157564, 0.17612275, ..., 0.97298069, 0.9842133 ,
#        0.85093956])

# %%
sub = pd.read_csv('/kaggle/input/playground-series-s5e11/sample_submission.csv')
sub[sub.columns[1]] = probs

# %%
sub
# Out:
#             id  loan_paid_back
# 0       593994        0.941326
# 1       593995        0.981576
# 2       593996        0.176123
# 3       593997        0.934551
# 4       593998        0.966983
# ...        ...             ...
# 254564  848558        0.991693
# 254565  848559        0.904097
# 254566  848560        0.972981
# 254567  848561        0.984213
# 254568  848562        0.850940
#
# [254569 rows x 2 columns]

# %%
sub.to_csv('submission_ordinal.csv', index=False)
